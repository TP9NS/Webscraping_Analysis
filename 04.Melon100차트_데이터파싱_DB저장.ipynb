# %% [markdown]
# ### BeautifulSoup
# * select() 함수 사용
# * melon 100 chart 데이터 파싱

# %%
import re
import requests
from bs4 import BeautifulSoup
from pprint import pprint

url = 'https://www.melon.com/chart/index.htm'

headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

res = requests.get(url, headers=headers)
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')    
    atag_list = soup.select("a[href*='playSong']")
    
    # [{},{}]
    song_list = [] # 100곡의 song list
    for idx, atag in enumerate(atag_list,1):
        print(f'순서 = {idx}')
        # 1곡의 song 정보를 저장할 dict
        song_dict = {}
        # song 제목
        title = atag.text
        song_dict['title'] = title
        
        # song id 추출하기
        href = atag['href']        
        matched = re.search(r'(\d+)\)', href)
        if matched:
            song_id = matched.group(1) # group(0) 38589554) // group(1) 38589554
        song_dict['id'] = song_id
            
        # 노래 상세정보 url
        song_url = f'https://www.melon.com/song/detail.htm?songId={song_id}'
        song_dict['url'] = song_url
        
        song_list.append(song_dict)
        
    # song_list 확인
    pprint(len(song_list))
    pprint(song_list[:3])    
else:
    print(f'Error Code = {res.status_code}')
# Out:
# 순서 = 1
# 순서 = 2
# 순서 = 3
# 순서 = 4
# 순서 = 5
# 순서 = 6
# 순서 = 7
# 순서 = 8
# 순서 = 9
# 순서 = 10
# 순서 = 11
# 순서 = 12
# 순서 = 13
# 순서 = 14
# 순서 = 15
# 순서 = 16
# 순서 = 17
# 순서 = 18
# 순서 = 19
# 순서 = 20
# 순서 = 21
# 순서 = 22
# 순서 = 23
# 순서 = 24
# 순서 = 25
# 순서 = 26
# 순서 = 27
# 순서 = 28
# 순서 = 29
# 순서 = 30
# 순서 = 31
# 순서 = 32
# 순서 = 33
# 순서 = 34
# 순서 = 35
# 순서 = 36
# 순서 = 37
# 순서 = 38
# 순서 = 39
# 순서 = 40
# 순서 = 41
# 순서 = 42
# 순서 = 43
# 순서 = 44
# 순서 = 45
# 순서 = 46
# 순서 = 47
# 순서 = 48
# 순서 = 49
# 순서 = 50
# 순서 = 51
# 순서 = 52
# 순서 = 53
# 순서 = 54
# 순서 = 55
# 순서 = 56
# 순서 = 57
# 순서 = 58
# 순서 = 59
# 순서 = 60
# 순서 = 61
# 순서 = 62
# 순서 = 63
# 순서 = 64
# 순서 = 65
# 순서 = 66
# 순서 = 67
# 순서 = 68
# 순서 = 69
# 순서 = 70
# 순서 = 71
# 순서 = 72
# 순서 = 73
# 순서 = 74
# 순서 = 75
# 순서 = 76
# 순서 = 77
# 순서 = 78
# 순서 = 79
# 순서 = 80
# 순서 = 81
# 순서 = 82
# 순서 = 83
# 순서 = 84
# 순서 = 85
# 순서 = 86
# 순서 = 87
# 순서 = 88
# 순서 = 89
# 순서 = 90
# 순서 = 91
# 순서 = 92
# 순서 = 93
# 순서 = 94
# 순서 = 95
# 순서 = 96
# 순서 = 97
# 순서 = 98
# 순서 = 99
# 순서 = 100
# 100
# [{'id': '38589554',
#   'title': 'TOO BAD (feat. Anderson .Paak)',
#   'url': 'https://www.melon.com/song/detail.htm?songId=38589554'},
#  {'id': '38429074',
#   'title': '모르시나요(PROD.로코베리)',
#   'url': 'https://www.melon.com/song/detail.htm?songId=38429074'},
#  {'id': '38629386',
#   'title': 'like JENNIE',
#   'url': 'https://www.melon.com/song/detail.htm?songId=38629386'}]

# %% [markdown]
# ### 곡상세 정보 추출하기

# %%
import re
import requests
from bs4 import BeautifulSoup

headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

# Song 100곡의 상세정보 목록을 저장할 list 선언
song_lyric_list = list()
print('===> 100 곡 노래 파싱 시작')
for idx,song in enumerate(song_list,1):
    print(f'==> {idx} {song['title']}')
    # Song 1곡의 상세정보를 저장할 dict 선언
    song_lyric_dict = dict()
    
    res = requests.get(song['url'], headers=headers)
    if res.ok:
        soup = BeautifulSoup(res.text,'html.parser')
        song_lyric_dict['곡명'] = song['title']
        
        singer_span = soup.select_one("a[href*='goArtistDetail'] span")
        song_lyric_dict['가수'] = singer_span.text
        
        song_dd = soup.select('div.meta dd') #song_dd는 ResultSet타입, song_dd[0]는 Tag 타입입
        if song_dd:
            song_lyric_dict['앨범'] = song_dd[0].text
            song_lyric_dict['발매일'] = song_dd[1].text
            song_lyric_dict['장르'] = song_dd[2].text
        
        # Song 상세정보 링크
        song_lyric_dict['detail_url'] = song['url']
            
        # 좋아요 건수
        song_id = song['id']
        ajax_url = f'https://www.melon.com/commonlike/getSongLike.json?contsIds={song_id}'
        res = requests.get(ajax_url, headers=headers)
        if res.ok:
            song_lyric_dict['좋아요'] = res.json()['contsLike'][0]['SUMMCNT']
        
        # 노래 가사     
        lyric_div = soup.select('div#d_video_summary')
        if lyric_div:
            lyric = lyric_div[0].text
        else:
            lyric = ''            
        
        # \n\r\t 특수문자를 찾는 Pattern객체 생성
        pattern = re.compile(r'[\n\r\t]')
        song_lyric_dict['가사'] = pattern.sub('', lyric)
        
        # list에 상세정보 담은 dict를 저장
        song_lyric_list.append(song_lyric_dict)
    else:
        print(f'Error Code = {res.status_code}')
        
print(len(song_lyric_list))
pprint(song_lyric_list[:2])
print('===> 100 곡 노래 파싱 끝')
# Out:
# ===> 100 곡 노래 파싱 시작
# ==> 1 TOO BAD (feat. Anderson .Paak)
# ==> 2 모르시나요(PROD.로코베리)
# ==> 3 like JENNIE
# ==> 4 Drowning
# ==> 5 HOME SWEET HOME (feat. 태양, 대성)
# ==> 6 나는 반딧불
# ==> 7 REBEL HEART
# ==> 8 Whiplash
# ==> 9 오늘만 I LOVE YOU
# ==> 10 APT.
# ==> 11 HOT
# ==> 12 HAPPY
# ==> 13 ATTITUDE
# ==> 14 toxic till the end
# ==> 15 내게 사랑이 뭐냐고 물어본다면
# ==> 16 Flower
# ==> 17 I DO ME
# ==> 18 PO￦ER
# ==> 19 TAKE ME
# ==> 20 미치게 그리워서
# ==> 21 소나기
# ==> 22 한 페이지가 될 수 있게
# ==> 23 Welcome to the Show
# ==> 24 천상연
# ==> 25 Dash
# ==> 26 사랑은 늘 도망가
# ==> 27 Supernova
# ==> 28 청춘만화
# ==> 29 예뻤어
# ==> 30 DRIP
# ==> 31 Die With A Smile
# ==> 32 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# ==> 33 슬픈 초대장
# ==> 34 우리들의 블루스
# ==> 35 Love wins all
# ==> 36 UP (KARINA Solo)
# ==> 37 MY LOVE(2025)
# ==> 38 RIZZ
# ==> 39 온기
# ==> 40 내 이름 맑음
# ==> 41 청혼하지 않을 이유를 못 찾았어
# ==> 42 Island
# ==> 43 The Chase
# ==> 44 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# ==> 45 사랑인가 봐
# ==> 46 Chroma Drift
# ==> 47 모래 알갱이
# ==> 48 12:32 (A to T)
# ==> 49 무제(無題) (Untitled, 2014)
# ==> 50 Home
# ==> 51 첫 만남은 계획대로 되지 않아
# ==> 52 다시 만날 수 있을까
# ==> 53 고민중독
# ==> 54 너의 모든 순간
# ==> 55 이제 나만 믿어요
# ==> 56 비의 랩소디
# ==> 57 How Sweet
# ==> 58 Magnetic
# ==> 59 에피소드
# ==> 60 봄날
# ==> 61 모든 날, 모든 순간 (Every day, Every Moment)
# ==> 62 나는 아픈 건 딱 질색이니까
# ==> 63 주저하는 연인들을 위해
# ==> 64 너와의 모든 지금
# ==> 65 다정히 내 이름을 부르면
# ==> 66 Mantra
# ==> 67 Seven (feat. Latto) - Clean Ver.
# ==> 68 Do or Die
# ==> 69 Supersonic
# ==> 70 헤어지자 말해요
# ==> 71 무지개
# ==> 72 너에게 닿기를
# ==> 73 I AM
# ==> 74 Sweet Dreams (feat. Miguel)
# ==> 75 London Boy
# ==> 76 인생찬가
# ==> 77 이렇게 좋아해 본 적이 없어요
# ==> 78 Polaroid
# ==> 79 인사
# ==> 80 Small girl (feat. 도경수(D.O.))
# ==> 81 Hype Boy
# ==> 82 미안해 미워해 사랑해
# ==> 83 취중고백
# ==> 84 사막에서 꽃을 피우듯
# ==> 85 Armageddon
# ==> 86 연애편지
# ==> 87 Ditto
# ==> 88 어제보다 슬픈 오늘
# ==> 89 DRAMA
# ==> 90 살기 위해서
# ==> 91 녹아내려요
# ==> 92 Sticky
# ==> 93 해야 (HEYA)
# ==> 94 숙녀에게
# ==> 95 Supernatural
# ==> 96 earthquake
# ==> 97 벚꽃 엔딩
# ==> 98 Igloo
# ==> 99 number one girl
# ==> 100 보금자리
# 100
# [{'detail_url': 'https://www.melon.com/song/detail.htm?songId=38589554',
#   '가사': '‘G’, ‘A.P’“Let me kill ’em like I usually do, Man.” Check it How do '
#         'you do?‘Tiki-Taka’ 난무 불이나 축이듯, 땀이 주르르르륵빛 쬐, Beautiful (That’s cool) '
#         '살짝쿵 손만 잡고 짝짝꿍 볼 맞장구게슴츠르레, G’azm 오르게 Dang, Is she that good?! Baby '
#         'Girl! Too bad for me There you go! Toot that! As for me?All I want! '
#         'Is in arms’ reach Break me off! Passionately Baby Girl! Too bad for '
#         'meThere you go! Toot that! As for me?All I want! Is in arms’ reach '
#         'Break me off! Passionately 긴가민가 어딘가 아리까리해Flirting인가? Bluffing인가? U '
#         'got me bad MBTI가 SEXY TYPE 하니 내 색시나 해GD be like that N.G M이 나이 Zett“I '
#         'don’t think so.”Baby Girl! Too bad for me There you go! Toot that! As '
#         'for me?All I want! Is in arms’ reach Break me off! Passionately Baby '
#         'Girl! Too bad for me There you go! Toot that! As for me?All I want! '
#         'Is in arms’ reachBreak me off! Passionately You do somethin’ (to me) '
#         'The chills runnin’ (thru me) I feel somethin’ (pull me) I’m still '
#         'runnin’ (til’ I reach) You do somethin’ (to me) The chills runnin’ '
#         '(thru me) I feel somethin’ (pull me) I’m still runnin’ (til’ I '
#         'reach)Come do something to me Come do something to me Come do '
#         'something to me Too hot to touch, Show meCome do something to me Come '
#         'do something to me Come do something to me 1, 2, You Too. Shall we? '
#         'Baby Girl! Too bad for me There you go! Toot that! As for me?All I '
#         'want! Is in arms’ reach Break me off! Passionately Baby Girl! Too bad '
#         'for me There you go! Toot that! As for me?All I want! Is in arms’ '
#         'reachBreak me off! Passionately You do somethin’ (to me) The chills '
#         'runnin’ (thru me) I feel somethin’ (pull me) I’m still runnin’ (til’ '
#         'I reach) You do somethin’ (to me) The chills runnin’ (thru me) I feel '
#         'somethin’ (pull me) I’m still runnin’ (til’ I reach) You do somethin’ '
#         'The chills runnin’ I feel somethin’ I’m still runnin’ (til’ I reach) '
#         'You do somethin’ The chills runnin’ I feel somethin’ I’m still '
#         'runnin’',
#   '가수': 'G-DRAGON',
#   '곡명': 'TOO BAD (feat. Anderson .Paak)',
#   '발매일': '2025.02.25',
#   '앨범': 'Übermensch',
#   '장르': '랩/힙합',
#   '좋아요': 124825},
#  {'detail_url': 'https://www.melon.com/song/detail.htm?songId=38429074',
#   '가사': '찬바람 불어오니그대 생각에 눈물짓네인사 없이 떠나시던 날그리움만 남겨놓고그리워 글썽이는 내 가슴속에오늘 그대 수천 번은 '
#         '다녀가시네나는 목놓아 그대를 소리쳐 불러도그댄 아무런 대답조차 하지 않네요..기다리는 나를 왜 모르시나요어느 계절마다 난 '
#         '기다리는데그저 소리 없이 울수록 서러워 서러워돌아와요 나의 그대여모르시나요눈물은 한없이 쏟아져 내려도슬픈 나의 두 눈은 끝내 '
#         '마를 날 없네나의 이별은 이토록 왜 가슴 시린지왜 나 혼자만 이렇게 또 가슴 아픈지기다리는 나를 왜 모르시나요어느 계절마다 '
#         '난 기다리는데그저 소리 없이 울수록 서러워 서러워돌아와요 나의 그대여모르시나요..찬바람 불어오니그대 생각에 눈물짓네인사 없이 '
#         '떠나시던 날그리움만 두고가네',
#   '가수': '조째즈',
#   '곡명': '모르시나요(PROD.로코베리)',
#   '발매일': '2025.01.07',
#   '앨범': '모르시나요',
#   '장르': '발라드',
#   '좋아요': 58763}]
# ===> 100 곡 노래 파싱 끝

# %% [markdown]
# #### song_lyric_lists를 DataFrame으로 저장하기

# %%
# [{'가수';'BTS','앨범':''},{}]
import pandas as pd

#컬럼명을 설정하면서 empty DataFrame 객체생성
song_list_df = pd.DataFrame(columns=['곡명','가수','앨범','발매일','장르','detail_url','좋아요','가사'])

for song_lyric in song_lyric_list: #[ {},{},{} ]
    df_new_row = pd.DataFrame.from_records([song_lyric])
    song_list_df = pd.concat([song_list_df, df_new_row])
    
song_list_df.head(3)
# Out:
#                                곡명           가수          앨범         발매일    장르  \
# 0  TOO BAD (feat. Anderson .Paak)     G-DRAGON  Übermensch  2025.02.25  랩/힙합
# 0                모르시나요(PROD.로코베리)          조째즈       모르시나요  2025.01.07   발라드
# 0                     like JENNIE  제니 (JENNIE)        Ruby  2025.03.07    댄스
#
#                                           detail_url     좋아요  \
# 0  https://www.melon.com/song/detail.htm?songId=3...  124825
# 0  https://www.melon.com/song/detail.htm?songId=3...   58763
# 0  https://www.melon.com/song/detail.htm?songId=3...   54894
#
#                                                   가사
# 0  ‘G’, ‘A.P’“Let me kill ’em like I usually do, ...
# 0  찬바람 불어오니그대 생각에 눈물짓네인사 없이 떠나시던 날그리움만 남겨놓고그리워 글썽...
# 0  Come on, it’s gon be f hardSpecial edition and...

# %% [markdown]
# #### song_lyric_lists를 Json 파일로 저장
# * json 파일로 저장해야 DataFrame으로 저장하기 용이함

# %%
import json

with open('data/songs100.json','w',encoding='utf-8') as file:
    json.dump(song_lyric_list, file)

# %% [markdown]
# ### Json File을 DataFrame (표데이터) 객체로 저장하기

# %%
import pandas as pd

song_df = pd.read_json('data/songs100.json')
print(type(song_df))
song_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                곡명           가수  \
# 0  TOO BAD (feat. Anderson .Paak)     G-DRAGON
# 1                모르시나요(PROD.로코베리)          조째즈
# 2                     like JENNIE  제니 (JENNIE)
# 3                        Drowning        WOODZ
# 4  HOME SWEET HOME (feat. 태양, 대성)     G-DRAGON
#
#                                앨범         발매일    장르  \
# 0                      Übermensch  2025.02.25  랩/힙합
# 1                           모르시나요  2025.01.07   발라드
# 2                            Ruby  2025.03.07    댄스
# 3                           OO-LI  2023.04.26  록/메탈
# 4  HOME SWEET HOME (feat. 태양, 대성)  2024.11.22  랩/힙합
#
#                                           detail_url     좋아요  \
# 0  https://www.melon.com/song/detail.htm?songId=3...  124825
# 1  https://www.melon.com/song/detail.htm?songId=3...   58763
# 2  https://www.melon.com/song/detail.htm?songId=3...   54894
# 3  https://www.melon.com/song/detail.htm?songId=3...  168246
# 4  https://www.melon.com/song/detail.htm?songId=3...  206183
#
#                                                   가사
# 0  ‘G’, ‘A.P’“Let me kill ’em like I usually do, ...
# 1  찬바람 불어오니그대 생각에 눈물짓네인사 없이 떠나시던 날그리움만 남겨놓고그리워 글썽...
# 2  Come on, it’s gon be f hardSpecial edition and...
# 3  미치도록 사랑했던지겹도록 다투었던네가 먼저 떠나고여긴 온종일 비가 왔어금세 턱 끝까...
# 4  You say, It’s changedShow must go on, Behave오랜...

# %%
# 가수 별 Row Counting
print(type(song_df['가수']))
song_df['가수'].value_counts().head()
# Out:
# <class 'pandas.core.series.Series'>
# 가수
# 임영웅            14
# G-DRAGON        6
# DAY6 (데이식스)     5
# PLAVE           5
# NewJeans        4
# Name: count, dtype: int64

# %%
# 장르 별 Row Counting
song_df['장르'].value_counts()
# Out:
# 장르
# 댄스            30
# 발라드           27
# 록/메탈          17
# 랩/힙합           7
# 발라드, 국내드라마     6
# 발라드, 인디음악      4
# R&B/Soul       3
# 성인가요/트로트       2
# POP            1
# 인디음악, 록/메탈     1
# 포크/블루스         1
# J-POP          1
# Name: count, dtype: int64

# %%
# 특정 가수의 노래 정보 출력하기
# Out:
#                   곡명   가수                 앨범         발매일    장르  \
# 0               에피소드  이무진               에피소드  2023.12.13  록/메탈
# 1   눈이 오잖아(Feat.헤이즈)  이무진   눈이 오잖아(Feat.헤이즈)  2021.12.03   발라드
# 2               청춘만화  이무진            만화 (滿花)  2024.10.07  록/메탈
# 3  청혼하지 않을 이유를 못 찾았어  이무진  청혼하지 않을 이유를 못 찾았어  2024.04.02   발라드
#
#                                                  url     좋아요  \
# 0  https://www.melon.com/song/detail.htm?songId=3...  118369
# 1  https://www.melon.com/song/detail.htm?songId=3...  154942
# 2  https://www.melon.com/song/detail.htm?songId=3...   34339
# 3  https://www.melon.com/song/detail.htm?songId=3...   46317
#
#                                                   가사
# 0  나는 말야버릇이 하나있어 그건 매일 잠에 들 시간마다잘 모아둔 기억 조각들 중잡히는...
# 1  한 달 좀 덜 된 기억들주머니에 넣은 채걷고 있어 몇 시간을혹시 몰라 네가 좋아했던...
# 2  우린 멋진 나이야좀 어리긴 하지만하고픈 일이나 가고픈 길해야 할 일들까지 많으니까우...
# 3  너에게 안 믿길 만큼 받은 게 참 많아요우선은 너 하나, 그리고 우리란 말사실 더할...

# %%
# unique 한 가수명을 리스트 형태로 출력하기
# Out:
# 52
# array(['G-DRAGON', 'IVE (아이브)', '황가람', 'aespa', '로제 (ROSÉ)', 'PLAVE',
#        'WOODZ', 'BOYNEXTDOOR', 'DAY6 (데이식스)', '재쓰비 (JAESSBEE)',
#        'BABYMONSTER', '로이킴', '이클립스 (ECLIPSE)', '임영웅', 'QWER', '이창섭',
#        '순순희(지환)', 'AKMU (악뮤)', '제니 (JENNIE)', '아이유', 'NewJeans', '성시경',
#        'TWS (투어스)', '너드커넥션 (Nerd Connection)', '(여자)아이들', '임재현', '프로미스나인',
#        '이영지', '이무진', '박재정', 'Crush', '아일릿(ILLIT)', '폴킴', '순순희', 'RIIZE',
#        'EXO', '경서예지', '부석순 (SEVENTEEN)', 'Lady Gaga', '범진',
#        'KISS OF LIFE', '잔나비', '멜로망스', '정국', '김민석', '윤하 (YOUNHA)',
#        '태연 (TAEYEON)', '지코 (ZICO)', '우디 (Woody)', 'BIGBANG (빅뱅)', '방탄소년단',
#        'YENA (최예나)'], dtype=object)

# %%
#앨범이 OST 인 노래는?
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.strings.accessor.StringMethods'>
#                                       곡명              가수  \
# 0                                    소나기  이클립스 (ECLIPSE)
# 1                              사랑은 늘 도망가             임영웅
# 2                               너의 모든 순간             성시경
# 3                            미안해 미워해 사랑해           Crush
# 4  모든 날, 모든 순간 (Every day, Every Moment)              폴킴
# 5                                 사랑인가 봐            멜로망스
#
#                          앨범         발매일          장르  \
# 0       선재 업고 튀어 OST Part 1  2024.04.08  발라드, 국내드라마
# 1        신사와 아가씨 OST Part.2  2021.10.11  발라드, 국내드라마
# 2       별에서 온 그대 OST Part.7  2014.02.12  발라드, 국내드라마
# 3         눈물의 여왕 OST Part.4  2024.03.24  발라드, 국내드라마
# 4   '키스 먼저 할까요?' OST Part.3  2018.03.20  발라드, 국내드라마
# 5  사랑인가 봐 (사내맞선 OST 스페셜 트랙)  2022.02.18  발라드, 국내드라마
#
#                                                  url     좋아요  \
# 0  https://www.melon.com/song/detail.htm?songId=3...  172038
# 1  https://www.melon.com/song/detail.htm?songId=3...  223712
# 2  https://www.melon.com/song/detail.htm?songId=4...  305502
# 3  https://www.melon.com/song/detail.htm?songId=3...  103103
# 4  https://www.melon.com/song/detail.htm?songId=3...  436552
# 5  https://www.melon.com/song/detail.htm?songId=3...  219969
#
#                                                   가사
# 0  그치지 않기를 바랬죠처음 그대 내게로 오던 그날에잠시 동안 적시는그런 비가 아니길간...
# 1  눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 2  이윽고 내가 한눈에너를 알아봤을 때모든 건 분명 달라지고 있었어내 세상은 널 알기 ...
# 3  It's the same day이렇게 너를다시 불러보는 잊고 있던 마음들과이제야 내...
# 4  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 5  너와 함께 하고 싶은 일들을상상하는 게요즘 내 일상이 되고너의 즐거워하는 모습을 보...

# %% [markdown]
# ### SqlAlchemy와 Pymysql을 사용하여 DataFrame을 RDB의 테이블로 저장하기

# %%
song_df.loc[song_df['가수'] == 'G-DRAGON']
# Out:
#                                 곡명        가수                              앨범  \
# 0   TOO BAD (feat. Anderson .Paak)  G-DRAGON                      Übermensch
# 4   HOME SWEET HOME (feat. 태양, 대성)  G-DRAGON  HOME SWEET HOME (feat. 태양, 대성)
# 17                           PO￦ER  G-DRAGON                           PO￦ER
# 18                         TAKE ME  G-DRAGON                      Übermensch
# 48         무제(無題) (Untitled, 2014)  G-DRAGON                             권지용
# 88                           DRAMA  G-DRAGON                      Übermensch
#
#            발매일        장르                                         detail_url  \
# 0   2025.02.25      랩/힙합  https://www.melon.com/song/detail.htm?songId=3...
# 4   2024.11.22      랩/힙합  https://www.melon.com/song/detail.htm?songId=3...
# 17  2024.10.31      랩/힙합  https://www.melon.com/song/detail.htm?songId=3...
# 18  2025.02.25        댄스  https://www.melon.com/song/detail.htm?songId=3...
# 48  2017.06.08  R&B/Soul  https://www.melon.com/song/detail.htm?songId=3...
# 88  2025.02.25       발라드  https://www.melon.com/song/detail.htm?songId=3...
#
#        좋아요                                                 가사
# 0   124825  ‘G’, ‘A.P’“Let me kill ’em like I usually do, ...
# 4   206183  You say, It’s changedShow must go on, Behave오랜...
# 17  155275  When G.D’s in the house (Übermensch)When G.D’s...
# 18   51997  M.B.T.M.I.U (My Baby Take Me I’m Yours)M.B.T.M...
# 48  311971  나에게 돌아오기가 어렵고 힘든 걸 알아이제 더는 상처받기가 두렵고 싫은 걸 알아네가...
# 88   36014  When every scene’s rolling in goodWhy you acti...

# %%
song_df.loc[song_df['가수'] == 'G-DRAGON',['곡명','장르']]
# Out:
#                                 곡명        장르
# 0   TOO BAD (feat. Anderson .Paak)      랩/힙합
# 4   HOME SWEET HOME (feat. 태양, 대성)      랩/힙합
# 17                           PO￦ER      랩/힙합
# 18                         TAKE ME        댄스
# 48         무제(無題) (Untitled, 2014)  R&B/Soul
# 88                           DRAMA       발라드

# %%
# 조건을 만족하는 특정 Row와 Slicing으로 선택된 특정 구간의 컬럼이 출력된다.
song_df.loc[song_df['가수'] == 'G-DRAGON','곡명':'장르'].reset_index(drop=True)
# Out:
#                                곡명        가수                              앨범  \
# 0  TOO BAD (feat. Anderson .Paak)  G-DRAGON                      Übermensch
# 1  HOME SWEET HOME (feat. 태양, 대성)  G-DRAGON  HOME SWEET HOME (feat. 태양, 대성)
# 2                           PO￦ER  G-DRAGON                           PO￦ER
# 3                         TAKE ME  G-DRAGON                      Übermensch
# 4         무제(無題) (Untitled, 2014)  G-DRAGON                             권지용
# 5                           DRAMA  G-DRAGON                      Übermensch
#
#           발매일        장르
# 0  2025.02.25      랩/힙합
# 1  2024.11.22      랩/힙합
# 2  2024.10.31      랩/힙합
# 3  2025.02.25        댄스
# 4  2017.06.08  R&B/Soul
# 5  2025.02.25       발라드

# %%
# unique 한 가수명을 리스트 형태로 출력하기
print(type(song_df['가수'].unique()))
print(len(song_df['가수'].unique()))
song_df['가수'].unique()
# Out:
# <class 'numpy.ndarray'>
# 55
# array(['G-DRAGON', '조째즈', '제니 (JENNIE)', 'WOODZ', '황가람', 'IVE (아이브)',
#        'aespa', 'BOYNEXTDOOR', '로제 (ROSÉ)', 'LE SSERAFIM (르세라핌)',
#        'DAY6 (데이식스)', '로이킴', '오반(OVAN)', 'KiiiKiii (키키)',
#        '이클립스 (ECLIPSE)', '이창섭', 'PLAVE', '임영웅', '이무진', 'BABYMONSTER',
#        'Lady Gaga', 'AKMU (악뮤)', '순순희(지환)', '아이유', '이예은', 'QWER',
#        'Hearts2Hearts (하츠투하츠)', '너드커넥션 (Nerd Connection)', '멜로망스',
#        'TWS (투어스)', '성시경', '임재현', 'NewJeans', '아일릿(ILLIT)', '방탄소년단', '폴킴',
#        '(여자)아이들', '잔나비', '재쓰비 (JAESSBEE)', '경서예지', '정국', '프로미스나인', '박재정',
#        '10CM', 'j-hope', '범진', '이영지', 'Crush', '김민석', '우디 (Woody)', '순순희',
#        'KISS OF LIFE', '송필근', '지수 (JISOO)', '버스커 버스커'], dtype=object)

# %%
#앨범이 OST 인 노래는?
print(type(song_df['앨범'].str))

song_df.loc[song_df['앨범'].str.contains('OST')]
# Out:
# <class 'pandas.core.strings.accessor.StringMethods'>
#                                        곡명              가수  \
# 20                                    소나기  이클립스 (ECLIPSE)
# 25                              사랑은 늘 도망가             임영웅
# 44                                 사랑인가 봐            멜로망스
# 53                               너의 모든 순간             성시경
# 60  모든 날, 모든 순간 (Every day, Every Moment)              폴킴
# 81                            미안해 미워해 사랑해           Crush
#
#                           앨범         발매일          장르  \
# 20       선재 업고 튀어 OST Part 1  2024.04.08  발라드, 국내드라마
# 25        신사와 아가씨 OST Part.2  2021.10.11  발라드, 국내드라마
# 44  사랑인가 봐 (사내맞선 OST 스페셜 트랙)  2022.02.18  발라드, 국내드라마
# 53       별에서 온 그대 OST Part.7  2014.02.12  발라드, 국내드라마
# 60   '키스 먼저 할까요?' OST Part.3  2018.03.20  발라드, 국내드라마
# 81         눈물의 여왕 OST Part.4  2024.03.24  발라드, 국내드라마
#
#                                            detail_url     좋아요  \
# 20  https://www.melon.com/song/detail.htm?songId=3...  177744
# 25  https://www.melon.com/song/detail.htm?songId=3...  225188
# 44  https://www.melon.com/song/detail.htm?songId=3...  222531
# 53  https://www.melon.com/song/detail.htm?songId=4...  307529
# 60  https://www.melon.com/song/detail.htm?songId=3...  436971
# 81  https://www.melon.com/song/detail.htm?songId=3...  106709
#
#                                                    가사
# 20  그치지 않기를 바랬죠처음 그대 내게로 오던 그날에잠시 동안 적시는그런 비가 아니길간...
# 25  눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 44  너와 함께 하고 싶은 일들을상상하는 게요즘 내 일상이 되고너의 즐거워하는 모습을 보...
# 53  이윽고 내가 한눈에너를 알아봤을 때모든 건 분명 달라지고 있었어내 세상은 널 알기 ...
# 60  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 81  It's the same day이렇게 너를다시 불러보는 잊고 있던 마음들과이제야 내...

# %%
# 좋아요 건수가 가장 많은 가수는?
song_df.loc[song_df['좋아요'] == song_df['좋아요'].max()]
# Out:
#     곡명     가수                    앨범         발매일    장르  \
# 59  봄날  방탄소년단  YOU NEVER WALK ALONE  2017.02.13  랩/힙합
#
#                                            detail_url     좋아요  \
# 59  https://www.melon.com/song/detail.htm?songId=3...  517117
#
#                                                    가사
# 59  보고 싶다이렇게 말하니까 더 보고 싶다너희 사진을 보고 있어도보고 싶다너무 야속한 ...

# %%
# 좋아요 건수의 평균
mean_like_value = song_df['좋아요'].mean()
song_df.loc[song_df['좋아요'] >= mean_like_value].sort_values(by='좋아요',ascending=False).reset_index(drop=True)
song_df.columns
# Out:
# Index(['곡명', '가수', '앨범', '발매일', '장르', 'detail_url', '좋아요', '가사'], dtype='object')

# %%
#song_df.columns.drop(['detail_url', '가사사'])
song_df.loc[song_df['좋아요'] >= mean_like_value,song_df.columns.drop(['detail_url', '가사'])]\
    .sort_values(by='좋아요',ascending=False).reset_index(drop=True)
# Out:
#                                             곡명                       가수  \
# 0                                           봄날                    방탄소년단
# 1                    어떻게 이별까지 사랑하겠어, 널 사랑하는 거지                AKMU (악뮤)
# 2                                 주저하는 연인들을 위해                      잔나비
# 3        모든 날, 모든 순간 (Every day, Every Moment)                       폴킴
# 4                                          예뻤어              DAY6 (데이식스)
# 5                                한 페이지가 될 수 있게              DAY6 (데이식스)
# 6                                        벚꽃 엔딩                  버스커 버스커
# 7                      무제(無題) (Untitled, 2014)                 G-DRAGON
# 8                                     Hype Boy                 NewJeans
# 9                                     너의 모든 순간                      성시경
# 10                                       Ditto                 NewJeans
# 11                                        I AM                IVE (아이브)
# 12                                   사랑은 늘 도망가                      임영웅
# 13                                      사랑인가 봐                     멜로망스
# 14            Seven (feat. Latto) - Clean Ver.                       정국
# 15                               다정히 내 이름을 부르면                     경서예지
# 16                                        APT.                로제 (ROSÉ)
# 17                               Love wins all                      아이유
# 18              HOME SWEET HOME (feat. 태양, 대성)                 G-DRAGON
# 19                                        취중고백                      김민석
# 20                                    헤어지자 말해요                      박재정
# 21                                       HAPPY              DAY6 (데이식스)
# 22                                   이제 나만 믿어요                      임영웅
# 23                                   Supernova                    aespa
# 24                                         소나기           이클립스 (ECLIPSE)
# 25                         Welcome to the Show              DAY6 (데이식스)
# 26                                    Drowning                    WOODZ
# 27                             나는 아픈 건 딱 질색이니까                  (여자)아이들
# 28                Small girl (feat. 도경수(D.O.))                      이영지
# 29                            첫 만남은 계획대로 되지 않아                TWS (투어스)
# 30                                       PO￦ER                 G-DRAGON
# 31                                   How Sweet                 NewJeans
# 32  그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))  너드커넥션 (Nerd Connection)
# 33                                          인사                       범진
# 34                                        고민중독                     QWER
# 35                                      나는 반딧불                      황가람
# 36                                    Magnetic               아일릿(ILLIT)
# 37                              오늘만 I LOVE YOU              BOYNEXTDOOR
#
#                                             앨범         발매일          장르     좋아요
# 0                         YOU NEVER WALK ALONE  2017.02.13        랩/힙합  517117
# 1                                           항해  2019.09.25         발라드  481777
# 2                                           전설  2019.03.13  인디음악, 록/메탈  438857
# 3                      '키스 먼저 할까요?' OST Part.3  2018.03.20  발라드, 국내드라마  436971
# 4                          Every DAY6 February  2017.02.06        록/메탈  366413
# 5                     The Book of Us : Gravity  2019.07.15        록/메탈  348609
# 6                                   버스커 버스커 1집  2012.03.29        록/메탈  317896
# 7                                          권지용  2017.06.08    R&B/Soul  311971
# 8                  NewJeans 1st EP 'New Jeans'  2022.08.01          댄스  308766
# 9                          별에서 온 그대 OST Part.7  2014.02.12  발라드, 국내드라마  307529
# 10                              NewJeans 'OMG'  2022.12.19          댄스  303783
# 11                                    I've IVE  2023.04.10          댄스  228485
# 12                          신사와 아가씨 OST Part.2  2021.10.11  발라드, 국내드라마  225188
# 13                    사랑인가 봐 (사내맞선 OST 스페셜 트랙)  2022.02.18  발라드, 국내드라마  222531
# 14            Seven (feat. Latto) - Clean Ver.  2023.07.14          댄스  221553
# 15                  다정히 내 이름을 부르면 (경서예지 x 전건호)  2021.05.19         발라드  211485
# 16                                        APT.  2024.10.18          댄스  209879
# 17                                 The Winning  2024.01.24         발라드  207201
# 18              HOME SWEET HOME (feat. 태양, 대성)  2024.11.22        랩/힙합  206183
# 19                                        취중고백  2021.12.19         발라드  198169
# 20                                    1집 Alone  2023.04.20         발라드  186085
# 21                                    Fourever  2024.03.18        록/메탈  184350
# 22                           내일은 미스터트롯 우승자 특전곡  2020.04.03    성인가요/트로트  180425
# 23                  Armageddon - The 1st Album  2024.05.13          댄스  179733
# 24                         선재 업고 튀어 OST Part 1  2024.04.08  발라드, 국내드라마  177744
# 25                                    Fourever  2024.03.18        록/메탈  172684
# 26                                       OO-LI  2023.04.26        록/메탈  168246
# 27                                           2  2024.01.29          댄스  167846
# 28                                  16 Fantasy  2024.06.21        랩/힙합  160518
# 29         TWS 1st Mini Album ‘Sparkling Blue’  2024.01.22          댄스  157967
# 30                                       PO￦ER  2024.10.31        랩/힙합  155275
# 31                                   How Sweet  2024.05.24          댄스  149332
# 32  그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))  2023.08.15         발라드  145658
# 33                                          인사  2021.12.24   발라드, 인디음악  143925
# 34                     1st Mini Album 'MANITO'  2024.04.01        록/메탈  142936
# 35                                      나는 반딧불  2024.10.21         발라드  133806
# 36                               SUPER REAL ME  2024.03.25          댄스  130998
# 37                              오늘만 I LOVE YOU  2025.01.06          댄스  129886

# %%
#song_df.columns.drop(['detail_url', '가사사'])
song_df.loc[song_df['좋아요'] >= mean_like_value,song_df.columns.drop(['detail_url', '가사'])]\
    .sort_values(by='좋아요',ascending=False).reset_index(drop=True)
# Out:
#                                             곡명                       가수  \
# 0                                           봄날                    방탄소년단
# 1                    어떻게 이별까지 사랑하겠어, 널 사랑하는 거지                AKMU (악뮤)
# 2                                 주저하는 연인들을 위해                      잔나비
# 3        모든 날, 모든 순간 (Every day, Every Moment)                       폴킴
# 4                                          예뻤어              DAY6 (데이식스)
# 5                                한 페이지가 될 수 있게              DAY6 (데이식스)
# 6                                        벚꽃 엔딩                  버스커 버스커
# 7                      무제(無題) (Untitled, 2014)                 G-DRAGON
# 8                                     Hype Boy                 NewJeans
# 9                                     너의 모든 순간                      성시경
# 10                                       Ditto                 NewJeans
# 11                                        I AM                IVE (아이브)
# 12                                   사랑은 늘 도망가                      임영웅
# 13                                      사랑인가 봐                     멜로망스
# 14            Seven (feat. Latto) - Clean Ver.                       정국
# 15                               다정히 내 이름을 부르면                     경서예지
# 16                                        APT.                로제 (ROSÉ)
# 17                               Love wins all                      아이유
# 18              HOME SWEET HOME (feat. 태양, 대성)                 G-DRAGON
# 19                                        취중고백                      김민석
# 20                                    헤어지자 말해요                      박재정
# 21                                       HAPPY              DAY6 (데이식스)
# 22                                   이제 나만 믿어요                      임영웅
# 23                                   Supernova                    aespa
# 24                                         소나기           이클립스 (ECLIPSE)
# 25                         Welcome to the Show              DAY6 (데이식스)
# 26                                    Drowning                    WOODZ
# 27                             나는 아픈 건 딱 질색이니까                  (여자)아이들
# 28                Small girl (feat. 도경수(D.O.))                      이영지
# 29                            첫 만남은 계획대로 되지 않아                TWS (투어스)
# 30                                       PO￦ER                 G-DRAGON
# 31                                   How Sweet                 NewJeans
# 32  그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))  너드커넥션 (Nerd Connection)
# 33                                          인사                       범진
# 34                                        고민중독                     QWER
# 35                                      나는 반딧불                      황가람
# 36                                    Magnetic               아일릿(ILLIT)
# 37                              오늘만 I LOVE YOU              BOYNEXTDOOR
#
#                                             앨범         발매일          장르     좋아요
# 0                         YOU NEVER WALK ALONE  2017.02.13        랩/힙합  517117
# 1                                           항해  2019.09.25         발라드  481777
# 2                                           전설  2019.03.13  인디음악, 록/메탈  438857
# 3                      '키스 먼저 할까요?' OST Part.3  2018.03.20  발라드, 국내드라마  436971
# 4                          Every DAY6 February  2017.02.06        록/메탈  366413
# 5                     The Book of Us : Gravity  2019.07.15        록/메탈  348609
# 6                                   버스커 버스커 1집  2012.03.29        록/메탈  317896
# 7                                          권지용  2017.06.08    R&B/Soul  311971
# 8                  NewJeans 1st EP 'New Jeans'  2022.08.01          댄스  308766
# 9                          별에서 온 그대 OST Part.7  2014.02.12  발라드, 국내드라마  307529
# 10                              NewJeans 'OMG'  2022.12.19          댄스  303783
# 11                                    I've IVE  2023.04.10          댄스  228485
# 12                          신사와 아가씨 OST Part.2  2021.10.11  발라드, 국내드라마  225188
# 13                    사랑인가 봐 (사내맞선 OST 스페셜 트랙)  2022.02.18  발라드, 국내드라마  222531
# 14            Seven (feat. Latto) - Clean Ver.  2023.07.14          댄스  221553
# 15                  다정히 내 이름을 부르면 (경서예지 x 전건호)  2021.05.19         발라드  211485
# 16                                        APT.  2024.10.18          댄스  209879
# 17                                 The Winning  2024.01.24         발라드  207201
# 18              HOME SWEET HOME (feat. 태양, 대성)  2024.11.22        랩/힙합  206183
# 19                                        취중고백  2021.12.19         발라드  198169
# 20                                    1집 Alone  2023.04.20         발라드  186085
# 21                                    Fourever  2024.03.18        록/메탈  184350
# 22                           내일은 미스터트롯 우승자 특전곡  2020.04.03    성인가요/트로트  180425
# 23                  Armageddon - The 1st Album  2024.05.13          댄스  179733
# 24                         선재 업고 튀어 OST Part 1  2024.04.08  발라드, 국내드라마  177744
# 25                                    Fourever  2024.03.18        록/메탈  172684
# 26                                       OO-LI  2023.04.26        록/메탈  168246
# 27                                           2  2024.01.29          댄스  167846
# 28                                  16 Fantasy  2024.06.21        랩/힙합  160518
# 29         TWS 1st Mini Album ‘Sparkling Blue’  2024.01.22          댄스  157967
# 30                                       PO￦ER  2024.10.31        랩/힙합  155275
# 31                                   How Sweet  2024.05.24          댄스  149332
# 32  그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))  2023.08.15         발라드  145658
# 33                                          인사  2021.12.24   발라드, 인디음악  143925
# 34                     1st Mini Album 'MANITO'  2024.04.01        록/메탈  142936
# 35                                      나는 반딧불  2024.10.21         발라드  133806
# 36                               SUPER REAL ME  2024.03.25          댄스  130998
# 37                              오늘만 I LOVE YOU  2025.01.06          댄스  129886

# %%
print(song_df['발매일'].max())

song_df.loc[song_df['발매일'] == song_df['발매일'].max()]
# Out:
# 2025.03.31
#             곡명          가수          앨범         발매일   장르  \
# 87  어제보다 슬픈 오늘  우디 (Woody)  어제보다 슬픈 오늘  2025.03.31  발라드
#
#                                            detail_url   좋아요  \
# 87  https://www.melon.com/song/detail.htm?songId=3...  5914
#
#                                                    가사
# 87  밤새도록 내리던 소낙비가 네 모습을 지울까네가 떠난 어제보다도 난 오늘이 더 슬퍼지...

# %%
# !pip show pymysql
# Out:
# Name: PyMySQL
# Version: 1.1.1
# Summary: Pure Python MySQL Driver
# Home-page:
# Author:
# Author-email: Inada Naoki <songofacandy@gmail.com>, Yutaka Matsubara <yutaka.matsubara@gmail.com>
# License: MIT License
# Location: C:\Users\vega2\anaconda3\Lib\site-packages
# Requires:
# Required-by:

# %% [markdown]
# ### DataFrame을 Table로 저장하기

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

engine = None
conn = None
try:
    # dialect+driver://username:password@host:port/database
    engine = create_engine('mysql+pymysql://python:python@localhost:3306/python_db?charset=utf8mb4')#, encoding='utf-8')
    print('engine', engine)
    print(type(engine), engine)
    conn = engine.connect()
    print(type(conn), conn)
    
    #song_df(DataFrame객체)를 songs 테이블로 저장하기 to_sql() 함수 사용
    song_df.to_sql(name='songs', con=engine, if_exists='replace', index=False)
finally:
    if conn is not None: 
        conn.close()
    if engine is not None:
        engine.dispose()
# Out:
# engine Engine(mysql+pymysql://python:***@localhost:3306/python_db?charset=utf8mb4)
# <class 'sqlalchemy.engine.base.Engine'> Engine(mysql+pymysql://python:***@localhost:3306/python_db?charset=utf8mb4)
# <class 'sqlalchemy.engine.base.Connection'> <sqlalchemy.engine.base.Connection object at 0x00000193F0BD4830>

# %% [markdown]
# ### 복사한 DataFrame을 Table로 저장
# * 컬럼명을 영문으로 변경
# * 인덱스를 1부터 시작하도록 변경하고 DataFrame 객체의 인덱스가 테이블의 PK(primary key)가 되도록 설정
# * 컬럼의 데이터 타입을 변경 (발매일을 DATE 타입으로 변경)

# %%
# 기존의 DataFrame의 복사본을 만들기 
table_df = song_df.copy()
table_df.columns = ['title','singer','album','release_date','genre','url','likes','lyric']
table_df.head(3)
# Out:
#                             title       singer       album release_date genre  \
# 0  TOO BAD (feat. Anderson .Paak)     G-DRAGON  Übermensch   2025.02.25  랩/힙합
# 1                모르시나요(PROD.로코베리)          조째즈       모르시나요   2025.01.07   발라드
# 2                     like JENNIE  제니 (JENNIE)        Ruby   2025.03.07    댄스
#
#                                                  url   likes  \
# 0  https://www.melon.com/song/detail.htm?songId=3...  124825
# 1  https://www.melon.com/song/detail.htm?songId=3...   58763
# 2  https://www.melon.com/song/detail.htm?songId=3...   54894
#
#                                                lyric
# 0  ‘G’, ‘A.P’“Let me kill ’em like I usually do, ...
# 1  찬바람 불어오니그대 생각에 눈물짓네인사 없이 떠나시던 날그리움만 남겨놓고그리워 글썽...
# 2  Come on, it’s gon be f hardSpecial edition and...

# %%
table_df.columns = ['title','singer','album','release_date','genre','url','likes','lyric']
table_df.head(2)
# Out:
#                             title     singer                           album  \
# 0  HOME SWEET HOME (feat. 태양, 대성)   G-DRAGON  HOME SWEET HOME (feat. 태양, 대성)
# 1                     REBEL HEART  IVE (아이브)                     IVE EMPATHY
#
#   release_date genre                                                url  \
# 0   2024.11.22  랩/힙합  https://www.melon.com/song/detail.htm?songId=3...
# 1   2025.01.13    댄스  https://www.melon.com/song/detail.htm?songId=3...
#
#     likes                                              lyric
# 0  179089  You say, It’s changedShow must go on, Behave오랜...
# 1   58009  시작은 항상 다 이룬 것처럼엔딩은 마치 승리한 것처럼겁내지 않고 마음을 쏟을래 내 ...

# %%
#index 값의 1 부터 시작하도록 설정
# import numpy as np

#index 변경
# table_df.index = np.arange(1, len(table_df)+1)
table_df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
table_df.head(2)
# Out:
#                             title    singer       album release_date genre  \
# 0  TOO BAD (feat. Anderson .Paak)  G-DRAGON  Übermensch   2025.02.25  랩/힙합
# 1                모르시나요(PROD.로코베리)       조째즈       모르시나요   2025.01.07   발라드
#
#                                                  url   likes  \
# 0  https://www.melon.com/song/detail.htm?songId=3...  124825
# 1  https://www.melon.com/song/detail.htm?songId=3...   58763
#
#                                                lyric
# 0  ‘G’, ‘A.P’“Let me kill ’em like I usually do, ...
# 1  찬바람 불어오니그대 생각에 눈물짓네인사 없이 떠나시던 날그리움만 남겨놓고그리워 글썽...

# %%
# url 컬럼 삭제하기 axis=1은 column, axis=0 은 Row
table_df.drop('url', axis=1, inplace=True)

# %%
table_df.columns
# Out:
# Index(['title', 'singer', 'album', 'release_date', 'genre', 'likes', 'lyric'], dtype='object')

# %% [markdown]
# #### DataFrame 객체 ==> Table 로 변환
# * ['title', 'singer', 'album', 'release_date', 'genre', 'likes', 'lyric']
# * table_df(DataFrame객체)를 songs100 테이블로 저장하기 to_sql() 함수 사용

# %%
import pymysql
import sqlalchemy

pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

engine = None
conn = None
try:
    engine = create_engine('mysql+pymysql://python:python@localhost:3306/python_db?charset=utf8mb4')
    conn = engine.connect()    

    table_df.to_sql(name='songs100', con=engine, if_exists='replace', index=True,\
                    index_label='id',
                    dtype={
                        'id':sqlalchemy.types.INTEGER(),
                        'title':sqlalchemy.types.VARCHAR(200),
                        'singer':sqlalchemy.types.VARCHAR(200),
                        'album':sqlalchemy.types.VARCHAR(200),
                        'release_date':sqlalchemy.types.DATE,
                        'genre':sqlalchemy.types.VARCHAR(200),
                        'likes':sqlalchemy.types.BigInteger,
                        'lyric':sqlalchemy.types.VARCHAR(5000)
                    })
    print('songs100 테이블 생성됨')
finally:
    if conn is not None: 
        conn.close()
    if engine is not None:
        engine.dispose()
# Out:
# songs100 테이블 생성됨

# %% [markdown]
# #### SQL 쿼리 결과를 DataFrame 객체로 저장하는 함수선언하기
# * read_sql_query() sql문을 실행한 결과를 DataFrame 객체로 반환해주는 함수

# %%
def search_album(keyword):
    sql = """select * from songs100 where album like %s;"""

    import pandas as pd
    import pymysql
    import sqlalchemy

    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine
    
    engine = None
    conn = None
    try:
        engine = create_engine('mysql+pymysql://python:python@localhost:3306/python_db?charset=utf8mb4')
        conn = engine.connect()

        album_df = pd.read_sql_query(sql, con=conn, params=('%' + keyword + '%',))
        print(album_df.shape)
        return album_df
    finally:
        print('finally')
        if conn is not None: 
            conn.close()
        if engine is not None:
            engine.dispose()

# %%
search_album('OST')
# Out:
# (6, 8)
# finally
#    id                                  title          singer  \
# 0  20                                    소나기  이클립스 (ECLIPSE)
# 1  25                              사랑은 늘 도망가             임영웅
# 2  44                                 사랑인가 봐            멜로망스
# 3  53                               너의 모든 순간             성시경
# 4  60  모든 날, 모든 순간 (Every day, Every Moment)              폴킴
# 5  81                            미안해 미워해 사랑해           Crush
#
#                       album release_date       genre   likes  \
# 0       선재 업고 튀어 OST Part 1   2024-04-08  발라드, 국내드라마  177744
# 1        신사와 아가씨 OST Part.2   2021-10-11  발라드, 국내드라마  225188
# 2  사랑인가 봐 (사내맞선 OST 스페셜 트랙)   2022-02-18  발라드, 국내드라마  222531
# 3       별에서 온 그대 OST Part.7   2014-02-12  발라드, 국내드라마  307529
# 4   '키스 먼저 할까요?' OST Part.3   2018-03-20  발라드, 국내드라마  436971
# 5         눈물의 여왕 OST Part.4   2024-03-24  발라드, 국내드라마  106709
#
#                                                lyric
# 0  그치지 않기를 바랬죠처음 그대 내게로 오던 그날에잠시 동안 적시는그런 비가 아니길간...
# 1  눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 2  너와 함께 하고 싶은 일들을상상하는 게요즘 내 일상이 되고너의 즐거워하는 모습을 보...
# 3  이윽고 내가 한눈에너를 알아봤을 때모든 건 분명 달라지고 있었어내 세상은 널 알기 ...
# 4  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 5  It's the same day이렇게 너를다시 불러보는 잊고 있던 마음들과이제야 내...
